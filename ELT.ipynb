# %% [markdown]
# # __ETL__
# MVP

# %% [markdown]
# We import the libraries and create the dataframes.

# %%
import pandas as pd
import numpy as np

# %%
# The 4 csv are imported for create the dataframes

netflix=pd.read_csv("Datasets/amazon_prime_titles.csv")
hulu=pd.read_csv("Datasets/hulu_titles.csv")
disney_plus=pd.read_csv("Datasets/disney_plus_titles.csv")
amazon_prime=pd.read_csv("Datasets/amazon_prime_titles.csv")

# %%
netflix.head(3)
# Out:
#   show_id   type                 title      director  \
# 0      s1  Movie   The Grand Seduction  Don McKellar
# 1      s2  Movie  Take Care Good Night  Girish Joshi
# 2      s3  Movie  Secrets of Deception   Josh Webber
#
#                                                 cast        country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...  United States
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...

# %%
hulu.head(3)
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
#
#          date_added  release_year rating duration               listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN        Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min  Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min        Action, Thriller
#
#                                          description
# 0  ​Comedian Ricky Velez bares it all with his ho...
# 1  Mark, a low end South London hitman recently r...
# 2  A hardened Arizona rancher tries to protect an...

# %%
disney_plus.head(3)
# Out:
#   show_id   type                                             title  \
# 0      s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2  Movie                            Ernest Saves Christmas
# 2      s3  Movie                      Ice Age: A Mammoth Christmas
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
#
#           date_added  release_year rating duration                  listed_in  \
# 0  November 26, 2021          2016   TV-G   23 min          Animation, Family
# 1  November 26, 2021          1988     PG   91 min                     Comedy
# 2  November 26, 2021          2011   TV-G   23 min  Animation, Comedy, Family
#
#                                          description
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...
# 2          Sid the Sloth is on Santa's naughty list.

# %%
amazon_prime.head(3)
# Out:
#   show_id   type                 title      director  \
# 0      s1  Movie   The Grand Seduction  Don McKellar
# 1      s2  Movie  Take Care Good Night  Girish Joshi
# 2      s3  Movie  Secrets of Deception   Josh Webber
#
#                                                 cast        country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...  United States
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...

# %% [markdown]
# . Create the __id__ field in each dataframe, which is composed of the first letter of the platform name
# . Create __platform__ field to have a better follow-up of which platform the row belongs to

# %%
#'id' field 
amazon_prime.insert(0,"id", ("a"+amazon_prime["show_id"]))

disney_plus.insert(0,"id", ("d"+disney_plus["show_id"]))

hulu.insert(0,"id", ("h"+hulu["show_id"]))

netflix.insert(0,"id", ("n"+amazon_prime["show_id"]))

# %%
#'platform' field
amazon_prime['platform']='amazonPrime'; disney_plus['platform']='disney'; netflix['platform']='netflix'; hulu['platform']='hulu'

# %% [markdown]
# .Now we concatenate all in a single dataframe using __concat()__ and reset the index.

# %%
DF_Proyect = pd.concat([amazon_prime, netflix, disney_plus, hulu], axis=0)

# %%
DF_Proyect.reset_index(drop=True, inplace=True)

# %%
DF_Proyect.sample(5)
# Out:
#            id show_id     type  \
# 2813   as2814   s2814    Movie
# 13088  ns3421   s3421  TV Show
# 16561  ns6894   s6894    Movie
# 8656   as8657   s8657    Movie
# 20031   ds696    s696  TV Show
#
#                                                  title         director  \
# 2813                               Code Of The Red Man    Edward Finney
# 13088             A French Village (English subtitled)              NaN
# 16561  Andy Peters: Question. Point. Exclamation Mark.  Steven Feinartz
# 8656                                 Sex and Chocolate     Gavin Millar
# 20031                          Miles From Tomorrowland              NaN
#
#                                                     cast        country  \
# 2813   Ted Adams, Chief Thurndercloud, Rick Vallin, D...            NaN
# 13088  Thierry Godard, Robin Renucci, Audrey Fleurot,...            NaN
# 16561                                        Andy Peters            NaN
# 8656          Dawn French, Phil Daniels, Michael Maloney            NaN
# 20031  Olivia Munn, Cullen McCarthy, Fiona Bishop, De...  United States
#
#              date_added  release_year rating   duration  \
# 2813                NaN          1942    18+     66 min
# 13088               NaN          2013    16+  3 Seasons
# 16561               NaN          2015    18+     49 min
# 8656                NaN          1997    16+     87 min
# 20031  December 1, 2019          2014   TV-Y  2 Seasons
#
#                                                listed_in  \
# 2813                                             Western
# 13088                                           TV Shows
# 16561  Arts, Entertainment, and Culture, Comedy, Spec...
# 8656                                      Drama, Romance
# 20031                  Action-Adventure, Animation, Kids
#
#                                              description     platform
# 2813   Nakoma, a wild stallion, threatens any animal ...  amazonPrime
# 13088  In French with English subtitles. This acclaim...      netflix
# 16561  Filmed at The Virgil in Los Angeles, Andy Pete...      netflix
# 8656   Bev, a warm and cuddly wife and mum who is hap...  amazonPrime
# 20031  Blastastic! Join Miles and his family in outer...       disney

# %%
# Columns datatypes
DF_Proyect.dtypes
# Out:
# id              object
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# platform        object
# dtype: object

# %%
print("Dataset size: ",DF_Proyect.shape," and the duplicated data: ", DF_Proyect.duplicated().sum())
# Out:
# Dataset size:  (23859, 14)  and the duplicated data:  0

# %%
#Number of nulls in columns

DF_Proyect.isnull().sum().sort_values()
# Out:
# id                  0
# show_id             0
# type                0
# title               0
# release_year        0
# listed_in           0
# platform            0
# description         4
# duration          479
# rating           1197
# cast             5729
# director         7707
# date_added      19057
# country         19664
# dtype: int64

# %% [markdown]
# .We replace the null values with __'G'__ in the rating field (maturity rating: “general for all audiences”)
# .Change to __lowercase__ all the fields content

# %%
DF_Proyect.rating.fillna('g', inplace=True)

# %%
#All the strings in the dataframe to lowercase

DF_Proyect['type'] = DF_Proyect['type'].str.lower()
DF_Proyect['title'] = DF_Proyect['title'].str.lower()
DF_Proyect['director'] = DF_Proyect['director'].str.lower()
DF_Proyect['cast'] = DF_Proyect['cast'].str.lower()
DF_Proyect['country'] = DF_Proyect['country'].str.lower()
DF_Proyect['date_added'] = DF_Proyect['date_added'].str.lower()
DF_Proyect['rating'] = DF_Proyect['rating'].str.lower()
DF_Proyect['listed_in'] = DF_Proyect['listed_in'].str.lower()
DF_Proyect['description'] = DF_Proyect['description'].str.lower()
DF_Proyect['platform'] = DF_Proyect['platform'].str.lower()

# %% [markdown]
# .Duration --> __Duration_type__, __Duration_int__
#
# .We __convert__ the __date_added__ field to __datetime(Y/m/d)__

# %%
#Convert all the elements of duration in str, now we split in two duration, duration_int(integer) and duration_type(string)
DF_Proyect['duration']=DF_Proyect['duration'].astype(str)

DF_Proyect['duration_int']= DF_Proyect['duration'].apply(lambda x:x.split()[0])
DF_Proyect['duration_type']=DF_Proyect['duration'].apply(lambda x:str(x.split()[1:]))


#Remove duration column
DF_Proyect=DF_Proyect.drop(['duration'], axis=1)

# %%
#Now we convert to datetime "date_added" and we change to the format YYYY-MM-DD
DF_Proyect["date_added"] = pd.to_datetime(DF_Proyect['date_added'], errors='coerce')
DF_Proyect['date_added'] = DF_Proyect['date_added'].dt.strftime("%Y-%m-%d")

# %%
#DF_Proyect.to_csv("Datasets/DF_MoviesAndSeries.csv",index=False)

# %%
DF_Proyect
# Out:
#            id show_id     type                           title  \
# 0         as1      s1    movie             the grand seduction
# 1         as2      s2    movie            take care good night
# 2         as3      s3    movie            secrets of deception
# 3         as4      s4    movie              pink: staying true
# 4         as5      s5    movie                   monster maker
# ...       ...     ...      ...                             ...
# 23854  hs3069   s3069  tv show  star trek: the original series
# 23855  hs3070   s3070  tv show              star trek: voyager
# 23856  hs3071   s3071  tv show                       the fades
# 23857  hs3072   s3072  tv show               the twilight zone
# 23858  hs3073   s3073  tv show             tokyo magnitude 8.0
#
#              director                                               cast  \
# 0        don mckellar     brendan gleeson, taylor kitsch, gordon pinsent
# 1        girish joshi   mahesh manjrekar, abhay mahajan, sachin khedekar
# 2         josh webber  tom sizemore, lorenzo lamas, robert lasardo, r...
# 3      sonia anderson  interviews with: pink, adele, beyoncé, britney...
# 4        giles foster  harry dean stanton, kieran o'brien, george cos...
# ...               ...                                                ...
# 23854             NaN                                                NaN
# 23855             NaN                                                NaN
# 23856             NaN                                                NaN
# 23857             NaN                                                NaN
# 23858             NaN                                                NaN
#
#               country  date_added  release_year rating  \
# 0              canada  2021-03-30          2014      g
# 1               india  2021-03-30          2018    13+
# 2       united states  2021-03-30          2017      g
# 3       united states  2021-03-30          2014      g
# 4      united kingdom  2021-03-30          1989      g
# ...               ...         ...           ...    ...
# 23854   united states         NaN          1966  tv-pg
# 23855   united states         NaN          1997  tv-pg
# 23856  united kingdom         NaN          2011  tv-14
# 23857   united states         NaN          1959  tv-pg
# 23858           japan         NaN          2009  tv-14
#
#                                     listed_in  \
# 0                               comedy, drama
# 1                        drama, international
# 2                     action, drama, suspense
# 3                                 documentary
# 4                              drama, fantasy
# ...                                       ...
# 23854             action, adventure, classics
# 23855      action, adventure, science fiction
# 23856  horror, international, science fiction
# 23857     classics, science fiction, thriller
# 23858             anime, drama, international
#
#                                              description     platform  \
# 0      a small fishing village must procure a local d...  amazonprime
# 1      a metro family decides to fight a cyber crimin...  amazonprime
# 2      after a man discovers his wife is cheating on ...  amazonprime
# 3      pink breaks the mold once again, bringing her ...  amazonprime
# 4      teenage matt banting wants to work with a famo...  amazonprime
# ...                                                  ...          ...
# 23854  the 23rd century adventures of captain james t...         hulu
# 23855  catapulted into the distant sector of the gala...         hulu
# 23856  seventeen-year-old paul is haunted by apocalyp...         hulu
# 23857  rod serling's seminal anthology series focused...         hulu
# 23858  the devastation is unleashed in the span of se...         hulu
#
#       duration_int duration_type
# 0              113       ['min']
# 1              110       ['min']
# 2               74       ['min']
# 3               69       ['min']
# 4               45       ['min']
# ...            ...           ...
# 23854            3   ['Seasons']
# 23855            7   ['Seasons']
# 23856            1    ['Season']
# 23857            5   ['Seasons']
# 23858            1    ['Season']
#
# [23859 rows x 15 columns]
