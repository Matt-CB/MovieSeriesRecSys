# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_profiling

# %%
df_r= pd.read_parquet('DF.parquet')

# %%
df_r.head()
# Out:
#     id show_id   type                 title        director  \
# 0  as1      s1  movie   the grand seduction    don mckellar
# 1  as2      s2  movie  take care good night    girish joshi
# 2  as3      s3  movie  secrets of deception     josh webber
# 3  as4      s4  movie    pink: staying true  sonia anderson
# 4  as5      s5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#    date_added  release_year rating_x                listed_in  \
# 0  2021-03-30          2014        g            comedy, drama
# ...

# %%
#Number of rows and columns
df_r.shape
# Out:
# (23859, 16)

# %%
#Columns
df_r.columns.values
# Out:
# array(['id', 'show_id', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating_x', 'listed_in',
#        'description', 'platform', 'duration_int', 'duration_type',
#        'rating_y'], dtype=object)

# %%
df_r.describe()
# Out:
#        release_year      rating_y
# count  23859.000000  22998.000000
# mean    2008.567040      3.533443
# std       18.391662      0.048564
# min     1920.000000      3.336478
# 25%     2007.000000      3.500000
# 50%     2016.000000      3.533673
# 75%     2019.000000      3.567000
# max     2021.000000      3.724512

# %%
#Interactive report with pandas profiling
df_r.profile_report(title='EDA. recommendation movies and series')
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.00it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-03-21 08:03:59.705284&quot;&gt;&lt;title&gt;EDA. recommendation movies and series&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
#Export
#profile = df_r.profile_report(title='EDA. recommendation movies and series')
#profile.to_file("profile.html")
